# %%
import pandas as pd

# %%
# Read the CSV file
df = pd.read_csv(r"D:\CODING\LOCAL\school\COMP4621\Labs\project\data\to_be_used\2021-Aug-01_16_15_covid_Daily_.csv")

# Display the first 5 rows
df.head()
# Out:
#    Unnamed: 0                                               text  favorited  \
# 0           1  RT @rimeldemieI: ustedes realmente arriesgan c...      False
# 1           2  Some Covid Vaccine Hesitant Now Express Regret...      False
# 2           3  RT @NHSBartsHealth: Got questions about the Co...      False
# 3           4  RT @NicolasMaduro: #EnVivo 📹 | Jornada de trab...      False
# 4           5  RT @CongressMarsha: COVID cases are now on the...      False
#
#    favoriteCount replyToSN              created  truncated  replyToSID  \
# 0              0       NaN  2021-08-01 21:57:37      False         NaN
# 1              0       NaN  2021-08-01 21:57:37      False         NaN
# 2              0       NaN  2021-08-01 21:57:37      False         NaN
# 3              0       NaN  2021-08-01 21:57:37      False         NaN
# 4              0       NaN  2021-08-01 21:57:37      False         NaN
#
#                     id  replyToUID  \
# 0  1421953290313641990         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     15000 non-null  int64
#  1   text           15000 non-null  object
#  2   favorited      15000 non-null  bool
#  3   favoriteCount  15000 non-null  int64
#  4   replyToSN      1809 non-null   object
#  5   created        15000 non-null  object
#  6   truncated      15000 non-null  bool
#  7   replyToSID     1753 non-null   float64
#  8   id             15000 non-null  int64
#  9   replyToUID     1809 non-null   float64
#  10  statusSource   15000 non-null  object
#  11  screenName     15000 non-null  object
#  12  retweetCount   15000 non-null  int64
#  13  isRetweet      15000 non-null  bool
#  14  retweeted      15000 non-null  bool
#  15  longitude      1 non-null      float64
#  16  latitude       1 non-null      float64
# ...
